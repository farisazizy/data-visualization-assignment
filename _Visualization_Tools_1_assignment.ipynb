# %% [markdown]
# **Farishadi Mufakkir Azizy**
#
# ---
#
#
# 1301194003 | IF-42-GAB06

# %% [markdown]
# ## Assignment

# %% [markdown]
# Import necessary library

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Read the data

# %%
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)

# %% [markdown]
# Drop unnecessary columns

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can.head(2)
# Out:
#         OdName AreaName          RegName  ...  2011  2012  2013
# 0  Afghanistan     Asia    Southern Asia  ...  2203  2635  2004
# 1      Albania   Europe  Southern Europe  ...   539   620   603
#
# [2 rows x 38 columns]

# %% [markdown]
# Rename columns title

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %% [markdown]
# Add a 'Total' column

# %%
df_can['Total'] = df_can.sum(axis=1)

# %% [markdown]
# **Question 1:** Let's compare the number of immigrants from India and China from 1980 to 2013.

# %% [markdown]
# Step 1: Get the data set for China and India, and display dataframe.

# %%
### type your answer here
df_can.set_index("Country", inplace=True)
df_can.columns = list(map(str, df_can.columns))
df_can.loc['China']
# Out:
# Continent                  Asia
# Region             Eastern Asia
# DevName      Developing regions
# 1980                       5123
# 1981                       6682
# 1982                       3308
# 1983                       1863
# 1984                       1527
# 1985                       1816
# 1986                       1960
# 1987                       2643
# 1988                       2758
# 1989                       4323
# 1990                       8076
# 1991                      14255
# 1992                      10846
# 1993                       9817
# 1994                      13128
# 1995                      14398
# 1996                      19415
# 1997                      20475
# 1998                      21049
# 1999                      30069
# 2000                      35529
# 2001                      36434
# 2002                      31961
# 2003                      36439
# 2004                      36619
# 2005                      42584
# 2006                      33518
# 2007                      27642
# 2008                      30037
# 2009                      29622
# 2010                      30391
# 2011                      28502
# 2012                      33024
# 2013                      34129
# Total                    659962
# Name: China, dtype: object

# %%
df_can.loc['India']
# Out:
# Continent                  Asia
# Region            Southern Asia
# DevName      Developing regions
# 1980                       8880
# 1981                       8670
# 1982                       8147
# 1983                       7338
# 1984                       5704
# 1985                       4211
# 1986                       7150
# 1987                      10189
# 1988                      11522
# 1989                      10343
# 1990                      12041
# 1991                      13734
# 1992                      13673
# 1993                      21496
# 1994                      18620
# 1995                      18489
# 1996                      23859
# 1997                      22268
# 1998                      17241
# 1999                      18974
# 2000                      28572
# 2001                      31223
# 2002                      31889
# 2003                      27155
# 2004                      28235
# 2005                      36210
# 2006                      33848
# 2007                      28742
# 2008                      28261
# 2009                      29456
# 2010                      34235
# 2011                      27509
# 2012                      30933
# 2013                      33087
# Total                    691904
# Name: India, dtype: object

# %% [markdown]
# Step 2: Plot graph. We will explicitly specify line plot by passing in `kind` parameter to `plot()`.

# %%
### type your answer here
years = list(map(str, range(1980, 2014)))
China = df_can.loc['China', years]
India = df_can.loc['India', years]

# %%
China.index = China.index.map(int)
China.plot(kind='line')
India.index = India.index.map(int)
India.plot(kind='line')

plt.title('Immigration from China & India')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.legend(["China", "India"], loc="upper left")

plt.show() # need this line to show the updates made to the figure

# %% [markdown]
# **Question 2:** Compare the trend of top 5 countries that contributed the most to immigration to Canada.

# %% [markdown]
# Step 1: Get the data set for top 5 countries

# %%
### type your answer here
New = df_can.sort_values(by=['Total'], ascending=False)
New = New.head(5)
New
# Out:
#                                                    Continent  ...   Total
# Country                                                       ...
# India                                                   Asia  ...  691904
# China                                                   Asia  ...  659962
# United Kingdom of Great Britain and Northern Ir...    Europe  ...  551500
# Philippines                                             Asia  ...  511391
# Pakistan                                                Asia  ...  241600
#
# [5 rows x 38 columns]

# %% [markdown]
# Step 2: Plot graph

# %%
### type your answer here

New = New[years].transpose()
New.index = New.index.map(int)
New.plot(kind='line', figsize=(14, 8))

plt.title('Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# **Question 3**: Create an unstacked area plot of the 5 countries that contributed the least to immigration to Canada **from** 1980 to 2013. Use a transparency value of 0.55.

# %%
### type your answer here
New = df_can.sort_values(by=['Total'], ascending=True)
New = New.head(5)
New = New[years].transpose()

New.index = New.index.map(int) # let's change the index values of df_top5 to type integer for plotting
New.plot(kind='area', alpha=0.55, stacked=False)

plt.title('The Immigrant of Canada: Top 5 Least Contribution Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# **Question 4**: Display the immigration distribution for Greece, Albania, and Bulgaria for years 1980 - 2013? Use an overlapping plot with 15 bins and a transparency value of 0.35.

# %%
### type your answer here

New = df_can.loc[['Greece', 'Albania', 'Bulgaria'], years].transpose()

New.plot(kind='hist', bins=15, alpha=0.35)

plt.title('Histogram of Immigration from Greece, Albania, and Bulgaria from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# **Question 5:** Create a *horizontal* bar plot showing the *total* number of immigrants to Canada from the top 15 countries, for the period 1980 - 2013. Label each country with the total immigrant count.

# %% [markdown]
# Step 1: Get the data pertaining to the top 15 countries.

# %%
### type your answer here

New = df_can.sort_values(by=['Total'], ascending=False)
New = df_can['Total'].head(15)
New
# Out:
# Country
# India                                                   691904
# China                                                   659962
# United Kingdom of Great Britain and Northern Ireland    551500
# Philippines                                             511391
# Pakistan                                                241600
# United States of America                                241122
# Iran (Islamic Republic of)                              175923
# Sri Lanka                                               148358
# Republic of Korea                                       142581
# Poland                                                  139241
# Lebanon                                                 115359
# France                                                  109091
# Jamaica                                                 106431
# Viet Nam                                                 97146
# Romania                                                  93585
# Name: Total, dtype: int64

# %% [markdown]
# Step 2: Plot data:
#    1. Use `kind='barh'` to generate a bar chart with horizontal bars.
#    2. Make sure to choose a good size for the plot and to label your axes and to give the plot a title.
# <!--    3. Loop through the countries and annotate the immigrant population using the anotate function of the scripting interface. -->

# %%
### type your answer here

df_can.sort_values(by='Total', ascending=False, inplace=True)

New.plot(kind='barh', figsize=(12, 13))
plt.xlabel('Number of Immigrants')
plt.title('The Immigrant of Canada: Top 15 Country')

for index, value in enumerate(New): 
    label = format(int(value))
  
    plt.annotate(label, xy=(value - 47000 , index - 0.1), color='white')
    # plt.annotate(label, xy=(value - 47000, index - 0.10), color='white')

plt.show()

# %% [markdown]
# # Thank you for completing this lab!

# %% [markdown]
# <hr>
#
# Copyright &copy; 2019 [Cognitive Class](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
